# %% [markdown]
# # Data Science project - Binance API

# %% [markdown]
# ### Setup

# %%
apikey = 'RzDZPW1xWiZkXsgv5kv0gPr5IoI45Zw3BWjKYWtJUdsWt19d8sX49rCjXOJ6r74S'
secret = 'm2pwPGz511Bf9m9S2KCeJqrNlI7l5eFUYRqx2mJ5F9RBokOh7omnMzMFFK5T3804'

# %% [markdown]
# ### Import/Install dependencies

# %%
# !pip install python-binance mplfinance

# %%
import pandas as pd
from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager

# %% [markdown]
# ### Authenticate

# %%
client = Client(apikey, secret)

# %% [markdown]
# ### Get Tickers

# %%
tickers = client.get_all_tickers()
tickers
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.05228600'},
#  {'symbol': 'LTCBTC', 'price': '0.00222900'},
#  {'symbol': 'BNBBTC', 'price': '0.01040900'},
#  {'symbol': 'NEOBTC', 'price': '0.00043800'},
#  {'symbol': 'QTUMETH', 'price': '0.00250800'},
#  {'symbol': 'EOSETH', 'price': '0.00086800'},
#  {'symbol': 'SNTETH', 'price': '0.00002470'},
#  {'symbol': 'BNTETH', 'price': '0.00055600'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00012400'},
#  {'symbol': 'BNBETH', 'price': '0.19900000'},
#  {'symbol': 'BTCUSDT', 'price': '20916.50000000'},
#  {'symbol': 'ETHUSDT', 'price': '1093.90000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00000825'},
# ...

# %%
tickers_df = pd.DataFrame(tickers)

# %%
tickers_df.set_index('symbol', inplace=True)

# %%
tickers_df
# Out:
#                price
# symbol
# ETHBTC    0.05230100
# LTCBTC    0.00223000
# BNBBTC    0.01043500
# NEOBTC    0.00043700
# QTUMETH   0.00250700
# ...              ...
# ASRBUSD   3.15400000
# FIROBUSD  1.54200000
# NKNBUSD   0.07630000
# OPBNB     0.00233000
# OPEUR     0.48300000
#
# [2070 rows x 1 columns]

# %% [markdown]
# ### Get depth

# %%
depth = client.get_order_book(symbol='ETHBTC')
depth
# Out:
# {'lastUpdateId': 5412177572,
#  'bids': [['0.05232400', '4.77980000'],
#   ['0.05232300', '1.19440000'],
#   ['0.05232000', '2.38960000'],
#   ['0.05231900', '38.27120000'],
#   ['0.05231800', '10.49510000'],
#   ['0.05231700', '2.68930000'],
#   ['0.05231200', '11.52500000'],
#   ['0.05231100', '12.00000000'],
#   ['0.05231000', '11.97000000'],
#   ['0.05230500', '0.30000000'],
#   ['0.05230300', '0.07210000'],
#   ['0.05229800', '0.16810000'],
#   ['0.05229400', '25.88270000'],
#   ['0.05229200', '2.78770000'],
#   ['0.05229000', '0.15620000'],
#   ['0.05228900', '0.04240000'],
#   ['0.05228800', '0.03430000'],
#   ['0.05228600', '2.89580000'],
#   ['0.05228500', '2.00050000'],
#   ['0.05228300', '3.64420000'],
#   ['0.05228200', '5.26520000'],
#   ['0.05228100', '1.91090000'],
#   ['0.05228000', '1.78690000'],
#   ['0.05227800', '0.15900000'],
#   ['0.05227600', '7.38050000'],
#   ['0.05227500', '1.00740000'],
#   ['0.05227400', '3.70330000'],
#   ['0.05227300', '0.16240000'],
# ...

# %%
depth_df = pd.DataFrame(depth['bids'])
depth_df.columns = ['Price', 'Volume']
print(depth_df.dtypes)
depth_df.head()
# Out:
# Price     object
# Volume    object
# dtype: object
#         Price       Volume
# 0  0.05232400   4.77980000
# 1  0.05232300   1.19440000
# 2  0.05232000   2.38960000
# 3  0.05231900  38.27120000
# 4  0.05231800  10.49510000

# %% [markdown]
# ### Get historical data

# %%
client.get_historical_klines??
# Out:
# Signature:
# client.get_historical_klines(
#     symbol,
#     interval,
#     start_str=None,
#     end_str=None,
#     limit=1000,
#     klines_type: binance.enums.HistoricalKlinesType = <HistoricalKlinesType.SPOT: 1>,
# )
# Source:
#     def get_historical_klines(self, symbol, interval, start_str=None, end_str=None, limit=1000,
#                               klines_type: HistoricalKlinesType = HistoricalKlinesType.SPOT):
#         """Get Historical Klines from Binance
#
#         :param symbol: Name of symbol pair e.g BNBBTC
#         :type symbol: str
#         :param interval: Binance Kline interval
#         :type interval: str
#         :param start_str: optional - start date string in UTC format or timestamp in milliseconds
#         :type start_str: str|int
#         :param end_str: optional - end date string in UTC format or timestamp in milliseconds (default will fetch everything up to now)
#         :type end_str: str|int
#         :param limit: Default 1000; max 1000.
# ...

# %%
historical = client.get_historical_klines('ETHUSDT', Client.KLINE_INTERVAL_1DAY, '15 Jun 2021')

# %%
historical
# Out:
# [[1623715200000,
#   '2580.58000000',
#   '2640.00000000',
#   '2507.70000000',
#   '2543.54000000',
#   '599826.64933000',
#   1623801599999,
#   '1548303436.06276510',
#   1044834,
#   '296745.76720000',
#   '766423377.38332160',
#   '0'],
#  [1623801600000,
#   '2543.55000000',
#   '2556.19000000',
#   '2351.18000000',
#   '2367.89000000',
#   '624741.78358000',
#   1623887999999,
#   '1533734359.41300690',
#   896073,
#   '284039.92262000',
#   '698017754.35405180',
#   '0'],
#  [1623888000000,
#   '2368.02000000',
#   '2460.50000000',
#   '2306.00000000',
#   '2373.28000000',
#   '560667.58566000',
#   1623974399999,
#   '1338389545.00148260',
#   961448,
#   '270180.83506000',
#   '645226707.83642750',
#   '0'],
#  [1623974400000,
#   '2373.28000000',
#   '2378.00000000',
#   '2139.00000000',
#   '2234.09000000',
#   '778905.20197000',
#   1624060799999,
#   '1758827532.88334170',
#   1067542,
#   '371196.26583000',
#   '838571112.17782590',
#   '0'],
#  [1624060800000,
# ...

# %%
hist_df = pd.DataFrame(historical)
hist_df.head()
# Out:
#               0              1              2              3              4   \
# 0  1623715200000  2580.58000000  2640.00000000  2507.70000000  2543.54000000
# 1  1623801600000  2543.55000000  2556.19000000  2351.18000000  2367.89000000
# 2  1623888000000  2368.02000000  2460.50000000  2306.00000000  2373.28000000
# 3  1623974400000  2373.28000000  2378.00000000  2139.00000000  2234.09000000
# 4  1624060800000  2234.09000000  2278.82000000  2161.67000000  2164.67000000
#
#                 5              6                    7        8   \
# 0  599826.64933000  1623801599999  1548303436.06276510  1044834
# 1  624741.78358000  1623887999999  1533734359.41300690   896073
# 2  560667.58566000  1623974399999  1338389545.00148260   961448
# 3  778905.20197000  1624060799999  1758827532.88334170  1067542
# 4  496872.24997000  1624147199999  1104923869.41859910   763820
#
#                 9                   10 11
# 0  296745.76720000  766423377.38332160  0
# ...

# %%
hist_df.columns = ['Open Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close Time', 'Quote Asset Volume', 'Number of Trades', 'TB Base Volume', 'TB Quote Volume', 'Ignore']
hist_df.head()
# Out:
#        Open Time           Open           High            Low          Close  \
# 0  1623715200000  2580.58000000  2640.00000000  2507.70000000  2543.54000000
# 1  1623801600000  2543.55000000  2556.19000000  2351.18000000  2367.89000000
# 2  1623888000000  2368.02000000  2460.50000000  2306.00000000  2373.28000000
# 3  1623974400000  2373.28000000  2378.00000000  2139.00000000  2234.09000000
# 4  1624060800000  2234.09000000  2278.82000000  2161.67000000  2164.67000000
#
#             Volume     Close Time   Quote Asset Volume  Number of Trades  \
# 0  599826.64933000  1623801599999  1548303436.06276510           1044834
# 1  624741.78358000  1623887999999  1533734359.41300690            896073
# 2  560667.58566000  1623974399999  1338389545.00148260            961448
# 3  778905.20197000  1624060799999  1758827532.88334170           1067542
# 4  496872.24997000  1624147199999  1104923869.41859910            763820
#
#     TB Base Volume     TB Quote Volume Ignore
# ...

# %% [markdown]
# ### Preprocess Historical Data

# %%
hist_df.dtypes
# Out:
# Open Time              int64
# Open                  object
# High                  object
# Low                   object
# Close                 object
# Volume                object
# Close Time             int64
# Quote Asset Volume    object
# Number of Trades       int64
# TB Base Volume        object
# TB Quote Volume       object
# Ignore                object
# dtype: object

# %%
hist_df['Open Time'] = pd.to_datetime(hist_df['Open Time'] / 1000, unit='s')
hist_df['Close Time'] = pd.to_datetime(hist_df['Close Time'] / 1000, unit='s')

# %%
hist_df.tail()
# Out:
#      Open Time           Open           High            Low          Close  \
# 363 2022-06-13  1434.84000000  1455.00000000  1165.45000000  1209.82000000
# 364 2022-06-14  1209.35000000  1268.45000000  1075.80000000  1208.90000000
# 365 2022-06-15  1208.90000000  1250.00000000  1014.40000000  1237.52000000
# 366 2022-06-16  1237.53000000  1257.85000000  1051.55000000  1068.50000000
# 367 2022-06-17  1068.50000000  1118.00000000  1051.11000000  1104.74000000
#
#                Volume                    Close Time   Quote Asset Volume  \
# 363  3626351.66536000 2022-06-13 23:59:59.999000064  4611744120.81747040
# 364  2716493.80131000 2022-06-14 23:59:59.999000064  3217818700.12419390
# 365  3114823.13621000 2022-06-15 23:59:59.999000064  3493040697.13765710
# 366  1447386.83040000 2022-06-16 23:59:59.999000064  1649596819.73423900
# 367   672495.08690000 2022-06-17 23:59:59.999000064   734567847.97221800
#
#      Number of Trades    TB Base Volume      TB Quote Volume Ignore
# ...

# %%
numeric_columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'Quote Asset Volume', 'TB Base Volume', 'TB Quote Volume']
hist_df[numeric_columns] = hist_df[numeric_columns].apply(pd.to_numeric, axis=1) ### Swtich to numerci value

# %%
hist_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count   368.000000   368.000000   368.000000   368.000000  3.680000e+02
# mean   3059.379864  3151.651060  2948.278804  3055.368315  5.880681e+05
# std     805.403493   819.851704   789.114943   811.433758  3.728920e+05
# min    1068.500000  1118.000000  1014.400000  1068.500000  1.541439e+05
# 25%    2518.697500  2608.030000  2394.222500  2513.997500  3.788866e+05
# 50%    3050.555000  3159.260000  2950.105000  3050.475000  5.043959e+05
# 75%    3578.027500  3680.960000  3442.555000  3578.035000  6.783297e+05
# max    4807.980000  4868.000000  4713.890000  4807.980000  3.626352e+06
#
#        Quote Asset Volume  Number of Trades  TB Base Volume  TB Quote Volume
# count        3.680000e+02      3.680000e+02    3.680000e+02     3.680000e+02
# mean         1.649913e+09      1.026595e+06    2.926789e+05     8.218509e+08
# std          7.050248e+08      4.626599e+05    1.846529e+05     3.498765e+08
# ...

# %% [markdown]
# ### Vizualization

# %%
import mplfinance as mpf

# %%
mpf.plot(hist_df.set_index('Close Time').tail(100), type='candle', style='charles', volume=True, title= "ETHUSDT last 100 Days", mav=(10,20, 30))
